# %% [markdown]
# ### Technical Demonstration ACID operations - Mono Architecture

# %%
# Print information about the active SparkContext
sc
# Out:
# <SparkContext master=local[*] appName=PySparkShell>

# %%
# Import SparkSession (main entry point to Spark) and PySpark SQL functions
from pyspark.sql import SparkSession, functions as F

# Create or get an existing SparkSession
# This is how we initialize Spark in Python so we can read/write data, run SQL queries, etc.
spark = SparkSession.builder.appName('NoACID').getOrCreate()
# Out:
# 25/10/12 17:17:31 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.

# %%
# Load a structured dataset (the wine-quality CSV) into a Spark DataFrame,
df = spark.read.csv("/CA1/ACID/winequality-red.csv", header = True, inferSchema = True, sep = ";")
# Out:
# [Stage 0:>                                                          (0 + 1) / 1]

# %%
# Bring data to memory, cache the data
df.cache()
# Out:
# DataFrame[fixed acidity: double, volatile acidity: double, citric acid: double, residual sugar: double, chlorides: double, free sulfur dioxide: double, total sulfur dioxide: double, density: double, pH: double, sulphates: double, alcohol: double, quality: int]

# %%
# It is an action in spark, creates a spark job and count 
# all the rows using parallel processing (it is controlled by Spark) across the cpu cores in the local machine
df.count()
# Out:
# 1599

# %%
# Shows the dataFrame schema (columns + types)
df
# Out:
# DataFrame[fixed acidity: double, volatile acidity: double, citric acid: double, residual sugar: double, chlorides: double, free sulfur dioxide: double, total sulfur dioxide: double, density: double, pH: double, sulphates: double, alcohol: double, quality: int]

# %% [markdown]
# ###### Check for Nulls in the dataset

# %%
# Check for null values
# For each column c, create a new column named c that contains the number of null values in that column.
df_result = df.select([
    F.sum(F.when(F.col(c).isNull(), 1).otherwise(0)).alias(c)
    for c in df.columns
])

# Convert to pandas for a better visualisation
df_result_pd = df_result.toPandas().T  # Transpose for vertical display
df_result_pd.columns = ["null_count"] # Add column name null count
display(df_result_pd)
# Out:
#                       null_count
# fixed acidity                  0
# volatile acidity               0
# citric acid                    0
# residual sugar                 0
# chlorides                      0
# free sulfur dioxide            0
# total sulfur dioxide           0
# density                        0
# pH                             0
# sulphates                      0
# alcohol                        0
# quality                        0

# %% [markdown]
# ###### Check for Duplicate rows in the dataset

# %%
# Find duplicates rows
total_rows = df.count()
unique_rows = df.dropDuplicates().count()
duplicates = total_rows - unique_rows

print(f"Total rows: {total_rows}")
print(f"Unique rows: {unique_rows}")
print(f"Duplicate rows: {duplicates}")
# Out:
# Total rows: 1599
# Unique rows: 1359
# Duplicate rows: 240

# %%
# Delete duplicates
df = df.dropDuplicates()

# %%
# Find duplicates rows
total_rows = df.count() # total number of rows
unique_rows = df.dropDuplicates().count() # number of distinct rows, after removing duplicates only one copy of each unique record remains.
duplicates = total_rows - unique_rows # duplicates

print(f"Total rows: {total_rows}")
print(f"Unique rows: {unique_rows}")
print(f"Duplicate rows: {duplicates}")
# Out:
# Total rows: 1359
# Unique rows: 1359
# Duplicate rows: 0

# %% [markdown]
# ###### Prepare the dataset for inserting a row and for training neural network models. A copy of an existing row is created and modified (its label changed) and then inserted in the dataset to demonstrate that this simple architecture does not support ACID transactions.

# %%
# Add a column id + column label (quality >= 7 -> good wine)
df = (df.withColumn("id", F.monotonically_increasing_id())
         .withColumn("label", (F.col("quality") >= 7).cast("int")))

# %%
# Shows the new dataFrame schema (columns + types) after adding columns id and label
df
# Out:
# DataFrame[fixed acidity: double, volatile acidity: double, citric acid: double, residual sugar: double, chlorides: double, free sulfur dioxide: double, total sulfur dioxide: double, density: double, pH: double, sulphates: double, alcohol: double, quality: int, id: bigint, label: int]

# %%
# select -> This is a transformation, meaning Spark is defining what you want to do 
# (create a new logical plan), but not executing it yet. In other words, 
# create a new logical DataFrame that only keeps these three columns: id, label, and quality
# show -> this is the action that triggers Spark to actually execute the plan
df.select("id", "label", "quality").show()
# Out:
# +---+-----+-------+
# | id|label|quality|
# +---+-----+-------+
# |  0|    0|      4|
# |  1|    0|      5|
# |  2|    1|      7|
# |  3|    1|      7|
# |  4|    0|      6|
# |  5|    0|      5|
# |  6|    0|      5|
# |  7|    1|      7|
# |  8|    0|      5|
# |  9|    0|      6|
# | 10|    0|      6|
# | 11|    0|      5|
# | 12|    0|      6|
# | 13|    0|      6|
# | 14|    0|      6|
# | 15|    1|      7|
# | 16|    0|      6|
# | 17|    0|      5|
# | 18|    1|      7|
# | 19|    1|      8|
# +---+-----+-------+
# only showing top 20 rows

# %%
# reorganize the dataframe, removing the column quality
# Python list comprehension with all the columns removing id, quality and label 
feature_cols = [c for c in df.columns if c not in ("id", "quality", "label")]
# add the id column at the beggining and label at the end
df = df.select("id", *feature_cols, "label")

# %%
# Return a Python list containing the names of all the columns in the spark dataFrame, in order.
df.columns
# Out:
# ['id',
#  'fixed acidity',
#  'volatile acidity',
#  'citric acid',
#  'residual sugar',
#  'chlorides',
#  'free sulfur dioxide',
#  'total sulfur dioxide',
#  'density',
#  'pH',
#  'sulphates',
#  'alcohol',
#  'label']

# %%
# shuffle the dataframe using a seed (always the same order), then select the first element.
# then return a list with one element. [0] returns the first row of that list  
row = df.orderBy(F.rand(42)).limit(1).collect()[0]
# return the id
bad_id = row["id"]
# return the label for that row
orig_label = row["label"]
# Change the label
fix_label = 1 - orig_label

# %%
# build a condition id == bad_id
cond = F.col("id") == bad_id
# .withColumn()-> adds or replaces a column, transofrmation
# F.lit(fix_label)-> creates a literal constant value for every row
# where() -> tells Spark which rows you want, transformation
# From DataFrame df, take the rows that satisfy cond,
# and assign (or overwrite) their label column with the constant value fix_label
row_fix = df.where(cond).withColumn("label", F.lit(fix_label))

# %% [markdown]
# ###### The following two rows have identical feature values but different labels

# %%
# Convert that Spark Row object into a Python dictionary
print(row.asDict())
# Out:
# {'id': 255, 'fixed acidity': 8.9, 'volatile acidity': 0.875, 'citric acid': 0.13, 'residual sugar': 3.45, 'chlorides': 0.088, 'free sulfur dioxide': 4.0, 'total sulfur dioxide': 14.0, 'density': 0.9994, 'pH': 3.44, 'sulphates': 0.52, 'alcohol': 11.5, 'label': 0}

# %%
print(row_fix.first().asDict())
# Out:
# {'id': 255, 'fixed acidity': 8.9, 'volatile acidity': 0.875, 'citric acid': 0.13, 'residual sugar': 3.45, 'chlorides': 0.088, 'free sulfur dioxide': 4.0, 'total sulfur dioxide': 14.0, 'density': 0.9994, 'pH': 3.44, 'sulphates': 0.52, 'alcohol': 11.5, 'label': 1}

# %% [markdown]
# ###### HDFS CSV (DIRTY): INSERT  -> do not support ACID properties (no consistency)

# %%
# Write dataframe to hadoop
# Write the file in only one partition because I use coalesce, if I dont use coalesce it can create multiple partitions
# for the same file
df.coalesce(1).write.csv(
    path="/CA1/ACID/dirty/winequality-red",
    mode="overwrite",
    header=True
)

# %%
# Append the corrected row to hadoop (keeps old version of the row too)
row_fix.coalesce(1).write.csv(
    path="/CA1/ACID/dirty/winequality-red",
    mode="append",
    header=True
)

# %%
# read the csv from hadoop with sep = , because the files were written by Spark with the default delimiter = comma
df_in = spark.read.csv("/CA1/ACID/dirty/winequality-red", header = True, sep = ",")

# define list comprehension to create a list from df_in.
cols = [
    F.col(c).cast("double") if c not in ("id", "label") else F.col(c)
    for c in df_in.columns
]

# select(...) select the columns and transform the types because in csv they are strings
# column id is cast to bigint and label to int
# select(*cols) unpack the column type and pass them as arguments to select()
# withcolumn the same
# it is a transformation, nothing is executed yet
df_dirty = (df_in
               .select(*cols)
               .withColumn("id",F.col("id").cast("bigint"))
               .withColumn("label",F.col("label").cast("int")))

# %%
# how many partitions (tasks) are created to read the file 
df_in.rdd.getNumPartitions()
# Out:
# 2

# %%
# One row more than before because we duplicate a row with different label
df_dirty.count()
# Out:
# 1360

# %%
# select the column which is inserted twice
# group the DataFrame df_dirty by the column id
# count how many rows there are for that id
# count how many distinct values of label exist for that id
# condition where id = bad_id 
(df_dirty.groupBy("id")
 .agg(F.count("*").alias("n"), F.countDistinct("label").alias("label_versions"))
 .where(df_dirty["id"]==bad_id)).show()
# Out:
# +---+---+--------------+
# | id|  n|label_versions|
# +---+---+--------------+
# |255|  2|             2|
# +---+---+--------------+

# %%
# Replace invalid characters with underscores, sanitize the columns
for c in df_dirty.columns:
    df_dirty = df_dirty.withColumnRenamed(c, c.strip().lower().replace(" ", "_"))

# %%
df_dirty.count()
# Out:
# 1360

# %% [markdown]
# ### Train Keras ANN

# %%
#import sys
#print(sys.executable)  # sanity check: this is your system Python
#%pip install --user --break-system-packages "tensorflow>=2.16"  # or tensorflow-cpu

# %%
# import libraries to train ANN
import pandas as pd, numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow import keras
from tensorflow.keras import layers
# Out:
# 2025-10-12 17:20:04.230878: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# This list names the input columns — the variables that the model will use to make predictions
feature_cols = [
    "fixed_acidity", "volatile_acidity", "citric_acid", "residual_sugar",
    "chlorides", "free_sulfur_dioxide", "total_sulfur_dioxide",
    "density", "ph", "sulphates", "alcohol"
]

# this function takes a spark dataframe, as input and returns 
# NumPy arrays (X, y) — the standard format expected by TensorFlow
def to_numpy(sdf):
    # This collects the entire spark dataFrame into memory as a pandas dataFrame, it is an action
    # Trigger Spark to execute a job and produce a result.
    pdf = sdf.toPandas()
    # Select only the columns in the list above, and convert those Pandas columns into a 2D NumPy array
    # the data is stored as 32-bit floats (what TensorFlow expects).
    X = pdf[feature_cols].to_numpy(dtype=np.float32)
    # Select the label column and Converts it to a 1D NumPy array of integers
    y = pdf["label"].to_numpy(dtype=np.int64)
    return X, y

# %%
# call the function to_numpy
X, y = to_numpy(df_dirty)

# %%
# Split dataset into training and testing subsets
# test_size= 0.2 -> 20% of the data will go to the test set, and 80% will go to the training set
# If you have 1,599 samples: Training set is ~1,279 rows and Test set is 320 rows approximately
# random_state -> Ensure the same split every time you run the code, otherwise different 20% of rows go to X_test each time 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=7)

# %%
# Wrap the NumPy array X_train inside a pandas dataFrame to call describe
# we check values min and max to verify if they have different scales
pd.DataFrame(X_train).describe()
# Out:
#                 0            1            2            3            4   \
# count  1088.000000  1088.000000  1088.000000  1088.000000  1088.000000
# mean      8.330882     0.531700     0.273199     2.502252     0.088859
# std       1.736495     0.186346     0.196060     1.308558     0.052025
# min       4.600000     0.120000     0.000000     0.900000     0.012000
# 25%       7.100000     0.390000     0.090000     1.900000     0.070000
# 50%       7.900000     0.520000     0.260000     2.200000     0.079000
# 75%       9.300000     0.640000     0.430000     2.600000     0.091000
# max      15.900000     1.580000     1.000000    15.500000     0.611000
#
#                 5            6            7            8            9   \
# count  1088.000000  1088.000000  1088.000000  1088.000000  1088.000000
# mean     15.912683    46.302849     0.996734     3.309127     0.655882
# std      10.561567    31.897776     0.001862     0.153015     0.162066
# min       1.000000     6.000000     0.990070     2.740000     0.330000
# 25%       7.000000    22.000000     0.995615     3.210000     0.550000
# 50%      13.000000    38.000000     0.996710     3.310000     0.620000
# 75%      22.000000    62.000000     0.997853     3.400000     0.730000
# max      68.000000   165.000000     1.003690     4.010000     2.000000
#
#                 10
# count  1088.000000
# mean     10.421829
# std       1.067141
# min       8.400000
# 25%       9.500000
# 50%      10.200000
# 75%      11.100000
# max      14.900000

# %%
# we standardize because different features have different scales, and we want them all to 
# have equal importance for the model
# fit on the training set, use the same mean and std from training data to scale the test set
# it means that both datasets are on the same scale
sc = StandardScaler().fit(X_train)
X_train, X_test = sc.transform(X_train), sc.transform(X_test)

# %% [markdown]
# ###### First Model

# %%
# import libraries from tensorflow
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# build a model with two hidden layers
# Dense -> fully connected layer (each neuron connects to every neuron in the next layer)
# d is the number of input features
# activation function relu for both hidden layers
# The output layer has one neuron because it is a binary classification (good wine vs bad wine)
# The activation function is sigmoid, so the network outputs is a probability: 
# close to 0 -> class 0 (bad wine)
# close to 1 -> class 1 (good wine)
# optimizer adam -> to adjusts learning rates during training
# loss binary_crossentropy -> used for binary classification
# metric accuracy -> to measure performance
def build_model(d):
    model = Sequential()
    # Input + Hidden Layer 1
    model.add(Dense(64, input_dim=d, activation="relu"))
    
    # Hidden Layer 2
    model.add(Dense(32, activation="relu"))
    
    # Output Layer
    model.add(Dense(1, activation="sigmoid"))
    
    # Compile
    model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])
    return model

# %%
# build the model
model = build_model(X_train.shape[1])
# trains the neural network
# epochs = 200 -> Feeds training data through the model 200 times
# give the model unseen data (validation data) to evaluate after each epoch
# the model trains on mini-batches of 16 examples at a time
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=200, batch_size=16, verbose=2) # -> Model 1
# Out:
# /home/hduser/.local/lib/python3.12/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2025-10-10 14:49:34.234344: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Epoch 1/200
# 68/68 - 1s - 14ms/step - accuracy: 0.8649 - loss: 0.4218 - val_accuracy: 0.8529 - val_loss: 0.3914
# Epoch 2/200
# 68/68 - 0s - 3ms/step - accuracy: 0.8658 - loss: 0.3007 - val_accuracy: 0.8750 - val_loss: 0.3493
# Epoch 3/200
# 68/68 - 0s - 5ms/step - accuracy: 0.8833 - loss: 0.2775 - val_accuracy: 0.8566 - val_loss: 0.3403
# Epoch 4/200
# 68/68 - 0s - 3ms/step - accuracy: 0.8833 - loss: 0.2664 - val_accuracy: 0.8713 - val_loss: 0.3382
# Epoch 5/200
# 68/68 - 0s - 4ms/step - accuracy: 0.8888 - loss: 0.2616 - val_accuracy: 0.8676 - val_loss: 0.3416
# Epoch 6/200
# 68/68 - 0s - 3ms/step - accuracy: 0.8897 - loss: 0.2564 - val_accuracy: 0.8676 - val_loss: 0.3508
# Epoch 7/200
# 68/68 - 0s - 2ms/step - accuracy: 0.8934 - loss: 0.2523 - val_accuracy: 0.8750 - val_loss: 0.3491
# Epoch 8/200
# 68/68 - 0s - 3ms/step - accuracy: 0.8897 - loss: 0.2475 - val_accuracy: 0.8713 - val_loss: 0.3464
# Epoch 9/200
# 68/68 - 0s - 2ms/step - accuracy: 0.9007 - loss: 0.2457 - val_accuracy: 0.8750 - val_loss: 0.3566
# Epoch 10/200
# 68/68 - 0s - 2ms/step - accuracy: 0.9007 - loss: 0.2448 - val_accuracy: 0.8750 - val_loss: 0.3545
# Epoch 11/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9072 - loss: 0.2378 - val_accuracy: 0.8713 - val_loss: 0.3814
# Epoch 12/200
# 68/68 - 0s - 2ms/step - accuracy: 0.8925 - loss: 0.2381 - val_accuracy: 0.8787 - val_loss: 0.3646
# Epoch 13/200
# 68/68 - 0s - 3ms/step - accuracy: 0.8980 - loss: 0.2337 - val_accuracy: 0.8824 - val_loss: 0.3604
# Epoch 14/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9062 - loss: 0.2292 - val_accuracy: 0.8787 - val_loss: 0.3713
# Epoch 15/200
# 68/68 - 0s - 2ms/step - accuracy: 0.8998 - loss: 0.2284 - val_accuracy: 0.8824 - val_loss: 0.3621
# Epoch 16/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9062 - loss: 0.2259 - val_accuracy: 0.8897 - val_loss: 0.3776
# Epoch 17/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9062 - loss: 0.2237 - val_accuracy: 0.8897 - val_loss: 0.3682
# Epoch 18/200
# 68/68 - 0s - 2ms/step - accuracy: 0.9090 - loss: 0.2210 - val_accuracy: 0.8860 - val_loss: 0.3765
# Epoch 19/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9090 - loss: 0.2168 - val_accuracy: 0.8824 - val_loss: 0.3813
# Epoch 20/200
# 68/68 - 0s - 4ms/step - accuracy: 0.9081 - loss: 0.2172 - val_accuracy: 0.8860 - val_loss: 0.3789
# Epoch 21/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9118 - loss: 0.2121 - val_accuracy: 0.8897 - val_loss: 0.3954
# Epoch 22/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9136 - loss: 0.2074 - val_accuracy: 0.8897 - val_loss: 0.3981
# Epoch 23/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9136 - loss: 0.2070 - val_accuracy: 0.8860 - val_loss: 0.4016
# Epoch 24/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9154 - loss: 0.2030 - val_accuracy: 0.8860 - val_loss: 0.4108
# Epoch 25/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9127 - loss: 0.2017 - val_accuracy: 0.8824 - val_loss: 0.4145
# Epoch 26/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9136 - loss: 0.1998 - val_accuracy: 0.8897 - val_loss: 0.4085
# Epoch 27/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9200 - loss: 0.1958 - val_accuracy: 0.8860 - val_loss: 0.4148
# Epoch 28/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9182 - loss: 0.1965 - val_accuracy: 0.8860 - val_loss: 0.4221
# Epoch 29/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9164 - loss: 0.1941 - val_accuracy: 0.8860 - val_loss: 0.4247
# Epoch 30/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9246 - loss: 0.1892 - val_accuracy: 0.8897 - val_loss: 0.4237
# Epoch 31/200
# 68/68 - 0s - 2ms/step - accuracy: 0.9246 - loss: 0.1864 - val_accuracy: 0.8860 - val_loss: 0.4325
# Epoch 32/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9246 - loss: 0.1862 - val_accuracy: 0.8897 - val_loss: 0.4259
# Epoch 33/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9283 - loss: 0.1813 - val_accuracy: 0.8787 - val_loss: 0.4337
# Epoch 34/200
# 68/68 - 0s - 4ms/step - accuracy: 0.9283 - loss: 0.1775 - val_accuracy: 0.8897 - val_loss: 0.4446
# Epoch 35/200
# 68/68 - 0s - 4ms/step - accuracy: 0.9292 - loss: 0.1763 - val_accuracy: 0.8897 - val_loss: 0.4634
# Epoch 36/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9329 - loss: 0.1769 - val_accuracy: 0.8897 - val_loss: 0.4443
# Epoch 37/200
# 68/68 - 0s - 5ms/step - accuracy: 0.9301 - loss: 0.1737 - val_accuracy: 0.8824 - val_loss: 0.4650
# Epoch 38/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9301 - loss: 0.1714 - val_accuracy: 0.8860 - val_loss: 0.4761
# Epoch 39/200
# 68/68 - 0s - 4ms/step - accuracy: 0.9366 - loss: 0.1697 - val_accuracy: 0.8897 - val_loss: 0.4714
# Epoch 40/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9357 - loss: 0.1656 - val_accuracy: 0.8860 - val_loss: 0.4776
# Epoch 41/200
# 68/68 - 0s - 4ms/step - accuracy: 0.9375 - loss: 0.1637 - val_accuracy: 0.8824 - val_loss: 0.4737
# Epoch 42/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9311 - loss: 0.1625 - val_accuracy: 0.8824 - val_loss: 0.5031
# Epoch 43/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9320 - loss: 0.1669 - val_accuracy: 0.8860 - val_loss: 0.4791
# Epoch 44/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9393 - loss: 0.1563 - val_accuracy: 0.8787 - val_loss: 0.4978
# Epoch 45/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9467 - loss: 0.1559 - val_accuracy: 0.8824 - val_loss: 0.4839
# Epoch 46/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9449 - loss: 0.1565 - val_accuracy: 0.8787 - val_loss: 0.4928
# Epoch 47/200
# 68/68 - 0s - 4ms/step - accuracy: 0.9393 - loss: 0.1497 - val_accuracy: 0.8676 - val_loss: 0.5004
# Epoch 48/200
# 68/68 - 0s - 2ms/step - accuracy: 0.9375 - loss: 0.1515 - val_accuracy: 0.8824 - val_loss: 0.5085
# Epoch 49/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9439 - loss: 0.1469 - val_accuracy: 0.8750 - val_loss: 0.5290
# Epoch 50/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9458 - loss: 0.1459 - val_accuracy: 0.8676 - val_loss: 0.5095
# Epoch 51/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9449 - loss: 0.1431 - val_accuracy: 0.8860 - val_loss: 0.5295
# Epoch 52/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9449 - loss: 0.1478 - val_accuracy: 0.8713 - val_loss: 0.5206
# Epoch 53/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9403 - loss: 0.1395 - val_accuracy: 0.8750 - val_loss: 0.5315
# Epoch 54/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9467 - loss: 0.1363 - val_accuracy: 0.8824 - val_loss: 0.5476
# Epoch 55/200
# 68/68 - 0s - 5ms/step - accuracy: 0.9494 - loss: 0.1376 - val_accuracy: 0.8750 - val_loss: 0.5430
# Epoch 56/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9494 - loss: 0.1328 - val_accuracy: 0.8824 - val_loss: 0.5437
# Epoch 57/200
# 68/68 - 0s - 5ms/step - accuracy: 0.9504 - loss: 0.1338 - val_accuracy: 0.8750 - val_loss: 0.5263
# Epoch 58/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9531 - loss: 0.1297 - val_accuracy: 0.8824 - val_loss: 0.5860
# Epoch 59/200
# 68/68 - 1s - 8ms/step - accuracy: 0.9577 - loss: 0.1282 - val_accuracy: 0.8824 - val_loss: 0.5749
# Epoch 60/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9540 - loss: 0.1244 - val_accuracy: 0.8824 - val_loss: 0.5846
# Epoch 61/200
# 68/68 - 0s - 4ms/step - accuracy: 0.9586 - loss: 0.1229 - val_accuracy: 0.8860 - val_loss: 0.5867
# Epoch 62/200
# 68/68 - 0s - 4ms/step - accuracy: 0.9550 - loss: 0.1214 - val_accuracy: 0.8750 - val_loss: 0.5965
# Epoch 63/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9586 - loss: 0.1190 - val_accuracy: 0.8640 - val_loss: 0.6039
# Epoch 64/200
# 68/68 - 0s - 6ms/step - accuracy: 0.9596 - loss: 0.1177 - val_accuracy: 0.8750 - val_loss: 0.6314
# Epoch 65/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9596 - loss: 0.1149 - val_accuracy: 0.8824 - val_loss: 0.6320
# Epoch 66/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9586 - loss: 0.1145 - val_accuracy: 0.8713 - val_loss: 0.6281
# Epoch 67/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9596 - loss: 0.1118 - val_accuracy: 0.8824 - val_loss: 0.6059
# Epoch 68/200
# 68/68 - 0s - 6ms/step - accuracy: 0.9605 - loss: 0.1130 - val_accuracy: 0.8787 - val_loss: 0.6515
# Epoch 69/200
# 68/68 - 0s - 2ms/step - accuracy: 0.9550 - loss: 0.1110 - val_accuracy: 0.8676 - val_loss: 0.6320
# Epoch 70/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9586 - loss: 0.1077 - val_accuracy: 0.8713 - val_loss: 0.6556
# Epoch 71/200
# 68/68 - 0s - 4ms/step - accuracy: 0.9596 - loss: 0.1069 - val_accuracy: 0.8603 - val_loss: 0.6702
# Epoch 72/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9596 - loss: 0.1086 - val_accuracy: 0.8750 - val_loss: 0.6751
# Epoch 73/200
# 68/68 - 0s - 6ms/step - accuracy: 0.9651 - loss: 0.1024 - val_accuracy: 0.8640 - val_loss: 0.6662
# Epoch 74/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9715 - loss: 0.0983 - val_accuracy: 0.8824 - val_loss: 0.6887
# Epoch 75/200
# 68/68 - 0s - 4ms/step - accuracy: 0.9697 - loss: 0.0963 - val_accuracy: 0.8787 - val_loss: 0.6756
# Epoch 76/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9688 - loss: 0.0950 - val_accuracy: 0.8787 - val_loss: 0.7015
# Epoch 77/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9697 - loss: 0.0952 - val_accuracy: 0.8787 - val_loss: 0.7190
# Epoch 78/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9688 - loss: 0.0937 - val_accuracy: 0.8750 - val_loss: 0.7338
# Epoch 79/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9669 - loss: 0.0909 - val_accuracy: 0.8750 - val_loss: 0.7321
# Epoch 80/200
# 68/68 - 0s - 4ms/step - accuracy: 0.9752 - loss: 0.0890 - val_accuracy: 0.8750 - val_loss: 0.7380
# Epoch 81/200
# 68/68 - 0s - 6ms/step - accuracy: 0.9724 - loss: 0.0893 - val_accuracy: 0.8750 - val_loss: 0.7425
# Epoch 82/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9715 - loss: 0.0875 - val_accuracy: 0.8787 - val_loss: 0.7511
# Epoch 83/200
# 68/68 - 0s - 4ms/step - accuracy: 0.9752 - loss: 0.0829 - val_accuracy: 0.8676 - val_loss: 0.7706
# Epoch 84/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9706 - loss: 0.0855 - val_accuracy: 0.8676 - val_loss: 0.7648
# Epoch 85/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9706 - loss: 0.0858 - val_accuracy: 0.8676 - val_loss: 0.8016
# Epoch 86/200
# 68/68 - 0s - 4ms/step - accuracy: 0.9697 - loss: 0.0872 - val_accuracy: 0.8713 - val_loss: 0.8143
# Epoch 87/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9706 - loss: 0.0808 - val_accuracy: 0.8640 - val_loss: 0.8077
# Epoch 88/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9752 - loss: 0.0804 - val_accuracy: 0.8750 - val_loss: 0.8131
# Epoch 89/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9770 - loss: 0.0745 - val_accuracy: 0.8713 - val_loss: 0.8317
# Epoch 90/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9807 - loss: 0.0722 - val_accuracy: 0.8824 - val_loss: 0.7882
# Epoch 91/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9752 - loss: 0.0781 - val_accuracy: 0.8824 - val_loss: 0.8129
# Epoch 92/200
# 68/68 - 0s - 2ms/step - accuracy: 0.9798 - loss: 0.0734 - val_accuracy: 0.8787 - val_loss: 0.8627
# Epoch 93/200
# 68/68 - 0s - 5ms/step - accuracy: 0.9789 - loss: 0.0730 - val_accuracy: 0.8713 - val_loss: 0.8410
# Epoch 94/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9743 - loss: 0.0722 - val_accuracy: 0.8713 - val_loss: 0.8346
# Epoch 95/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9798 - loss: 0.0686 - val_accuracy: 0.8713 - val_loss: 0.8603
# Epoch 96/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9807 - loss: 0.0667 - val_accuracy: 0.8640 - val_loss: 0.8834
# Epoch 97/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9770 - loss: 0.0679 - val_accuracy: 0.8713 - val_loss: 0.8694
# Epoch 98/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9798 - loss: 0.0669 - val_accuracy: 0.8676 - val_loss: 0.8746
# Epoch 99/200
# 68/68 - 0s - 2ms/step - accuracy: 0.9835 - loss: 0.0637 - val_accuracy: 0.8640 - val_loss: 0.9115
# Epoch 100/200
# 68/68 - 0s - 2ms/step - accuracy: 0.9779 - loss: 0.0658 - val_accuracy: 0.8713 - val_loss: 0.9093
# Epoch 101/200
# 68/68 - 0s - 2ms/step - accuracy: 0.9816 - loss: 0.0603 - val_accuracy: 0.8713 - val_loss: 0.9252
# Epoch 102/200
# 68/68 - 0s - 2ms/step - accuracy: 0.9816 - loss: 0.0596 - val_accuracy: 0.8713 - val_loss: 0.9470
# Epoch 103/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9816 - loss: 0.0607 - val_accuracy: 0.8713 - val_loss: 0.9094
# Epoch 104/200
# 68/68 - 0s - 2ms/step - accuracy: 0.9844 - loss: 0.0565 - val_accuracy: 0.8713 - val_loss: 0.9911
# Epoch 105/200
# 68/68 - 0s - 5ms/step - accuracy: 0.9779 - loss: 0.0571 - val_accuracy: 0.8713 - val_loss: 0.9623
# Epoch 106/200
# 68/68 - 0s - 2ms/step - accuracy: 0.9807 - loss: 0.0554 - val_accuracy: 0.8713 - val_loss: 0.9327
# Epoch 107/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9871 - loss: 0.0523 - val_accuracy: 0.8750 - val_loss: 0.9737
# Epoch 108/200
# 68/68 - 0s - 2ms/step - accuracy: 0.9844 - loss: 0.0519 - val_accuracy: 0.8603 - val_loss: 0.9815
# Epoch 109/200
# 68/68 - 0s - 2ms/step - accuracy: 0.9862 - loss: 0.0500 - val_accuracy: 0.8713 - val_loss: 1.0125
# Epoch 110/200
# 68/68 - 0s - 4ms/step - accuracy: 0.9862 - loss: 0.0542 - val_accuracy: 0.8640 - val_loss: 1.0030
# Epoch 111/200
# 68/68 - 0s - 2ms/step - accuracy: 0.9881 - loss: 0.0516 - val_accuracy: 0.8603 - val_loss: 0.9892
# Epoch 112/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9890 - loss: 0.0508 - val_accuracy: 0.8750 - val_loss: 1.0290
# Epoch 113/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9871 - loss: 0.0478 - val_accuracy: 0.8603 - val_loss: 1.0124
# Epoch 114/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9871 - loss: 0.0469 - val_accuracy: 0.8713 - val_loss: 1.0627
# Epoch 115/200
# 68/68 - 0s - 2ms/step - accuracy: 0.9862 - loss: 0.0487 - val_accuracy: 0.8640 - val_loss: 1.0717
# Epoch 116/200
# 68/68 - 0s - 2ms/step - accuracy: 0.9890 - loss: 0.0467 - val_accuracy: 0.8603 - val_loss: 1.0823
# Epoch 117/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9890 - loss: 0.0428 - val_accuracy: 0.8640 - val_loss: 1.0591
# Epoch 118/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9862 - loss: 0.0472 - val_accuracy: 0.8566 - val_loss: 1.0909
# Epoch 119/200
# 68/68 - 0s - 2ms/step - accuracy: 0.9881 - loss: 0.0424 - val_accuracy: 0.8713 - val_loss: 1.1137
# Epoch 120/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9890 - loss: 0.0448 - val_accuracy: 0.8603 - val_loss: 1.0944
# Epoch 121/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9917 - loss: 0.0394 - val_accuracy: 0.8713 - val_loss: 1.1626
# Epoch 122/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9890 - loss: 0.0413 - val_accuracy: 0.8676 - val_loss: 1.1140
# Epoch 123/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9890 - loss: 0.0404 - val_accuracy: 0.8640 - val_loss: 1.1251
# Epoch 124/200
# 68/68 - 0s - 4ms/step - accuracy: 0.9917 - loss: 0.0376 - val_accuracy: 0.8750 - val_loss: 1.1358
# Epoch 125/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9917 - loss: 0.0385 - val_accuracy: 0.8676 - val_loss: 1.1369
# Epoch 126/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9917 - loss: 0.0365 - val_accuracy: 0.8676 - val_loss: 1.1381
# Epoch 127/200
# 68/68 - 0s - 4ms/step - accuracy: 0.9954 - loss: 0.0349 - val_accuracy: 0.8676 - val_loss: 1.1773
# Epoch 128/200
# 68/68 - 0s - 4ms/step - accuracy: 0.9917 - loss: 0.0376 - val_accuracy: 0.8566 - val_loss: 1.1959
# Epoch 129/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9917 - loss: 0.0358 - val_accuracy: 0.8676 - val_loss: 1.1950
# Epoch 130/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9936 - loss: 0.0355 - val_accuracy: 0.8640 - val_loss: 1.1714
# Epoch 131/200
# 68/68 - 0s - 5ms/step - accuracy: 0.9936 - loss: 0.0318 - val_accuracy: 0.8640 - val_loss: 1.1740
# Epoch 132/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9917 - loss: 0.0336 - val_accuracy: 0.8676 - val_loss: 1.2225
# Epoch 133/200
# 68/68 - 0s - 2ms/step - accuracy: 0.9926 - loss: 0.0326 - val_accuracy: 0.8566 - val_loss: 1.1922
# Epoch 134/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9945 - loss: 0.0309 - val_accuracy: 0.8566 - val_loss: 1.2281
# Epoch 135/200
# 68/68 - 0s - 4ms/step - accuracy: 0.9963 - loss: 0.0302 - val_accuracy: 0.8676 - val_loss: 1.2480
# Epoch 136/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9945 - loss: 0.0295 - val_accuracy: 0.8713 - val_loss: 1.2643
# Epoch 137/200
# 68/68 - 0s - 2ms/step - accuracy: 0.9936 - loss: 0.0284 - val_accuracy: 0.8566 - val_loss: 1.2512
# Epoch 138/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9945 - loss: 0.0277 - val_accuracy: 0.8566 - val_loss: 1.2615
# Epoch 139/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9945 - loss: 0.0317 - val_accuracy: 0.8676 - val_loss: 1.2645
# Epoch 140/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9936 - loss: 0.0277 - val_accuracy: 0.8603 - val_loss: 1.3086
# Epoch 141/200
# 68/68 - 0s - 2ms/step - accuracy: 0.9954 - loss: 0.0258 - val_accuracy: 0.8640 - val_loss: 1.3022
# Epoch 142/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9945 - loss: 0.0265 - val_accuracy: 0.8640 - val_loss: 1.2993
# Epoch 143/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9972 - loss: 0.0249 - val_accuracy: 0.8640 - val_loss: 1.3866
# Epoch 144/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9954 - loss: 0.0243 - val_accuracy: 0.8603 - val_loss: 1.3481
# Epoch 145/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9954 - loss: 0.0261 - val_accuracy: 0.8566 - val_loss: 1.3447
# Epoch 146/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9945 - loss: 0.0238 - val_accuracy: 0.8640 - val_loss: 1.3662
# Epoch 147/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9963 - loss: 0.0224 - val_accuracy: 0.8566 - val_loss: 1.3644
# Epoch 148/200
# 68/68 - 0s - 2ms/step - accuracy: 0.9963 - loss: 0.0225 - val_accuracy: 0.8640 - val_loss: 1.4247
# Epoch 149/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9972 - loss: 0.0209 - val_accuracy: 0.8713 - val_loss: 1.4096
# Epoch 150/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9963 - loss: 0.0236 - val_accuracy: 0.8640 - val_loss: 1.3851
# Epoch 151/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9991 - loss: 0.0215 - val_accuracy: 0.8603 - val_loss: 1.4617
# Epoch 152/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9991 - loss: 0.0198 - val_accuracy: 0.8676 - val_loss: 1.4864
# Epoch 153/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9991 - loss: 0.0224 - val_accuracy: 0.8640 - val_loss: 1.4875
# Epoch 154/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9972 - loss: 0.0212 - val_accuracy: 0.8603 - val_loss: 1.4461
# Epoch 155/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9835 - loss: 0.0423 - val_accuracy: 0.8603 - val_loss: 1.5103
# Epoch 156/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9945 - loss: 0.0250 - val_accuracy: 0.8493 - val_loss: 1.4853
# Epoch 157/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9972 - loss: 0.0207 - val_accuracy: 0.8640 - val_loss: 1.4575
# Epoch 158/200
# 68/68 - 0s - 5ms/step - accuracy: 0.9982 - loss: 0.0183 - val_accuracy: 0.8603 - val_loss: 1.4996
# Epoch 159/200
# 68/68 - 0s - 6ms/step - accuracy: 0.9982 - loss: 0.0192 - val_accuracy: 0.8640 - val_loss: 1.4591
# Epoch 160/200
# 68/68 - 0s - 4ms/step - accuracy: 0.9972 - loss: 0.0183 - val_accuracy: 0.8640 - val_loss: 1.5140
# Epoch 161/200
# 68/68 - 0s - 4ms/step - accuracy: 0.9982 - loss: 0.0180 - val_accuracy: 0.8529 - val_loss: 1.5862
# Epoch 162/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9963 - loss: 0.0229 - val_accuracy: 0.8493 - val_loss: 1.5045
# Epoch 163/200
# 68/68 - 0s - 4ms/step - accuracy: 0.9972 - loss: 0.0209 - val_accuracy: 0.8566 - val_loss: 1.4836
# Epoch 164/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9972 - loss: 0.0192 - val_accuracy: 0.8676 - val_loss: 1.5603
# Epoch 165/200
# 68/68 - 0s - 4ms/step - accuracy: 0.9991 - loss: 0.0144 - val_accuracy: 0.8640 - val_loss: 1.5532
# Epoch 166/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9991 - loss: 0.0163 - val_accuracy: 0.8603 - val_loss: 1.5716
# Epoch 167/200
# 68/68 - 0s - 5ms/step - accuracy: 0.9954 - loss: 0.0191 - val_accuracy: 0.8529 - val_loss: 1.5945
# Epoch 168/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9991 - loss: 0.0155 - val_accuracy: 0.8676 - val_loss: 1.5914
# Epoch 169/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9982 - loss: 0.0150 - val_accuracy: 0.8603 - val_loss: 1.6336
# Epoch 170/200
# 68/68 - 0s - 6ms/step - accuracy: 0.9982 - loss: 0.0141 - val_accuracy: 0.8603 - val_loss: 1.6056
# Epoch 171/200
# 68/68 - 0s - 4ms/step - accuracy: 0.9982 - loss: 0.0146 - val_accuracy: 0.8676 - val_loss: 1.6532
# Epoch 172/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9982 - loss: 0.0142 - val_accuracy: 0.8603 - val_loss: 1.6725
# Epoch 173/200
# 68/68 - 0s - 4ms/step - accuracy: 0.9991 - loss: 0.0122 - val_accuracy: 0.8713 - val_loss: 1.6768
# Epoch 174/200
# 68/68 - 0s - 4ms/step - accuracy: 0.9972 - loss: 0.0153 - val_accuracy: 0.8603 - val_loss: 1.6763
# Epoch 175/200
# 68/68 - 0s - 5ms/step - accuracy: 0.9982 - loss: 0.0144 - val_accuracy: 0.8640 - val_loss: 1.6960
# Epoch 176/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9982 - loss: 0.0127 - val_accuracy: 0.8676 - val_loss: 1.6965
# Epoch 177/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9982 - loss: 0.0132 - val_accuracy: 0.8676 - val_loss: 1.7109
# Epoch 178/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9991 - loss: 0.0114 - val_accuracy: 0.8713 - val_loss: 1.7617
# Epoch 179/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9991 - loss: 0.0110 - val_accuracy: 0.8713 - val_loss: 1.7698
# Epoch 180/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9991 - loss: 0.0125 - val_accuracy: 0.8676 - val_loss: 1.7248
# Epoch 181/200
# 68/68 - 0s - 5ms/step - accuracy: 0.9991 - loss: 0.0117 - val_accuracy: 0.8676 - val_loss: 1.7790
# Epoch 182/200
# 68/68 - 0s - 5ms/step - accuracy: 0.9972 - loss: 0.0135 - val_accuracy: 0.8676 - val_loss: 1.7784
# Epoch 183/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9991 - loss: 0.0113 - val_accuracy: 0.8676 - val_loss: 1.8449
# Epoch 184/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9972 - loss: 0.0141 - val_accuracy: 0.8824 - val_loss: 1.8055
# Epoch 185/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9945 - loss: 0.0226 - val_accuracy: 0.8713 - val_loss: 1.8765
# Epoch 186/200
# 68/68 - 0s - 4ms/step - accuracy: 0.9881 - loss: 0.0517 - val_accuracy: 0.8603 - val_loss: 1.6837
# Epoch 187/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9982 - loss: 0.0175 - val_accuracy: 0.8603 - val_loss: 1.6763
# Epoch 188/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9982 - loss: 0.0140 - val_accuracy: 0.8713 - val_loss: 1.7572
# Epoch 189/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9991 - loss: 0.0106 - val_accuracy: 0.8640 - val_loss: 1.7935
# Epoch 190/200
# 68/68 - 0s - 4ms/step - accuracy: 0.9991 - loss: 0.0096 - val_accuracy: 0.8603 - val_loss: 1.7735
# Epoch 191/200
# 68/68 - 0s - 4ms/step - accuracy: 0.9982 - loss: 0.0100 - val_accuracy: 0.8603 - val_loss: 1.8198
# Epoch 192/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9991 - loss: 0.0100 - val_accuracy: 0.8676 - val_loss: 1.8565
# Epoch 193/200
# 68/68 - 0s - 2ms/step - accuracy: 0.9991 - loss: 0.0101 - val_accuracy: 0.8640 - val_loss: 1.8300
# Epoch 194/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9991 - loss: 0.0087 - val_accuracy: 0.8676 - val_loss: 1.8399
# Epoch 195/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9982 - loss: 0.0116 - val_accuracy: 0.8676 - val_loss: 1.8258
# Epoch 196/200
# 68/68 - 0s - 4ms/step - accuracy: 0.9982 - loss: 0.0102 - val_accuracy: 0.8676 - val_loss: 1.8234
# Epoch 197/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9991 - loss: 0.0099 - val_accuracy: 0.8640 - val_loss: 1.8639
# Epoch 198/200
# 68/68 - 0s - 4ms/step - accuracy: 0.9982 - loss: 0.0104 - val_accuracy: 0.8566 - val_loss: 1.8828
# Epoch 199/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9991 - loss: 0.0105 - val_accuracy: 0.8603 - val_loss: 1.8699
# Epoch 200/200
# 68/68 - 0s - 3ms/step - accuracy: 0.9991 - loss: 0.0088 - val_accuracy: 0.8676 - val_loss: 1.8834

# %% [markdown]
# ###### Second Model (includes techniques to improve training and generalization)

# %%
# import libraries from tensorflow
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, BatchNormalization, Dropout
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# build a model with two hidden layers
# Dense -> fully connected layer (each neuron connects to every neuron in the next layer)
# d is the number of input features
# activation function relu for both hidden layers
# The output layer has one neuron because it is a binary classification (good wine vs bad wine)
# The activation function is sigmoid, so the network outputs is a probability: 
# close to 0 -> class 0 (bad wine)
# close to 1 -> class 1 (good wine)
# optimizer adam -> to adjusts learning rates during training
# loss binary_crossentropy -> used for binary classification
# metric accuracy -> to measure performance
# Three core techniques were added to make neural networks train better and 
# generalize well (Dropout, BatchNormalization and L2)
# EarlyStopping and ReduceLROnPlateau are callbacks that help your model train smarter 
# and avoid overfitting or wasting epochs
def build_model1(d):
    model = Sequential()
    
    # Input + Hidden Layer 1
    model.add(Dense(64, input_dim=d, activation="relu", kernel_regularizer=l2(0.001)))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))
    
    # Hidden Layer 2
    model.add(Dense(32, activation="relu", kernel_regularizer=l2(0.001)))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))
    
    # Output Layer
    model.add(Dense(1, activation="sigmoid"))
    
    # Compile
    model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])
    return model

es  = EarlyStopping(monitor="val_loss", patience=8, restore_best_weights=True)
rlr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=4, min_lr=1e-5)

# %%
# build the model
model1 = build_model1(X_train.shape[1])
# trains the neural network
# epochs = 200 -> Feeds training data through the model 200 times
# give the model unseen data (validation data) to evaluate after each epoch
# the model trains on mini-batches of 16 examples at a time
model1.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=200, batch_size=16, verbose=2, callbacks=[es, rlr]) # -> Model 2)
# Out:
# Epoch 1/200
# 68/68 - 2s - 28ms/step - accuracy: 0.5864 - loss: 0.8440 - val_accuracy: 0.8088 - val_loss: 0.6016 - learning_rate: 0.0010
# Epoch 2/200
# 68/68 - 0s - 5ms/step - accuracy: 0.7270 - loss: 0.6184 - val_accuracy: 0.8382 - val_loss: 0.5234 - learning_rate: 0.0010
# Epoch 3/200
# 68/68 - 0s - 3ms/step - accuracy: 0.7978 - loss: 0.5459 - val_accuracy: 0.8676 - val_loss: 0.4562 - learning_rate: 0.0010
# Epoch 4/200
# 68/68 - 0s - 3ms/step - accuracy: 0.8300 - loss: 0.4643 - val_accuracy: 0.8750 - val_loss: 0.4228 - learning_rate: 0.0010
# Epoch 5/200
# 68/68 - 0s - 3ms/step - accuracy: 0.8585 - loss: 0.4189 - val_accuracy: 0.8676 - val_loss: 0.3998 - learning_rate: 0.0010
# Epoch 6/200
# 68/68 - 0s - 3ms/step - accuracy: 0.8575 - loss: 0.4174 - val_accuracy: 0.8750 - val_loss: 0.3849 - learning_rate: 0.0010
# Epoch 7/200
# 68/68 - 0s - 3ms/step - accuracy: 0.8704 - loss: 0.3934 - val_accuracy: 0.8824 - val_loss: 0.3845 - learning_rate: 0.0010
# Epoch 8/200
# 68/68 - 0s - 3ms/step - accuracy: 0.8704 - loss: 0.3746 - val_accuracy: 0.8787 - val_loss: 0.3808 - learning_rate: 0.0010
# Epoch 9/200
# 68/68 - 0s - 3ms/step - accuracy: 0.8704 - loss: 0.3739 - val_accuracy: 0.8824 - val_loss: 0.3827 - learning_rate: 0.0010
# Epoch 10/200
# 68/68 - 0s - 3ms/step - accuracy: 0.8842 - loss: 0.3471 - val_accuracy: 0.8713 - val_loss: 0.3826 - learning_rate: 0.0010
# Epoch 11/200
# 68/68 - 0s - 3ms/step - accuracy: 0.8658 - loss: 0.3502 - val_accuracy: 0.8824 - val_loss: 0.3670 - learning_rate: 0.0010
# Epoch 12/200
# 68/68 - 0s - 3ms/step - accuracy: 0.8860 - loss: 0.3381 - val_accuracy: 0.8934 - val_loss: 0.3726 - learning_rate: 0.0010
# Epoch 13/200
# 68/68 - 0s - 3ms/step - accuracy: 0.8722 - loss: 0.3488 - val_accuracy: 0.8860 - val_loss: 0.3726 - learning_rate: 0.0010
# Epoch 14/200
# 68/68 - 0s - 3ms/step - accuracy: 0.8759 - loss: 0.3443 - val_accuracy: 0.8897 - val_loss: 0.3715 - learning_rate: 0.0010
# Epoch 15/200
# 68/68 - 0s - 3ms/step - accuracy: 0.8704 - loss: 0.3447 - val_accuracy: 0.8897 - val_loss: 0.3718 - learning_rate: 0.0010
# Epoch 16/200
# 68/68 - 0s - 3ms/step - accuracy: 0.8631 - loss: 0.3506 - val_accuracy: 0.8860 - val_loss: 0.3697 - learning_rate: 5.0000e-04
# Epoch 17/200
# 68/68 - 0s - 3ms/step - accuracy: 0.8778 - loss: 0.3228 - val_accuracy: 0.8824 - val_loss: 0.3668 - learning_rate: 5.0000e-04
# Epoch 18/200
# 68/68 - 0s - 3ms/step - accuracy: 0.8842 - loss: 0.3225 - val_accuracy: 0.8824 - val_loss: 0.3696 - learning_rate: 5.0000e-04
# Epoch 19/200
# 68/68 - 0s - 4ms/step - accuracy: 0.8833 - loss: 0.3294 - val_accuracy: 0.8860 - val_loss: 0.3712 - learning_rate: 5.0000e-04
# Epoch 20/200
# 68/68 - 0s - 3ms/step - accuracy: 0.8906 - loss: 0.3195 - val_accuracy: 0.8897 - val_loss: 0.3728 - learning_rate: 5.0000e-04
# Epoch 21/200
# 68/68 - 0s - 3ms/step - accuracy: 0.8897 - loss: 0.3245 - val_accuracy: 0.8824 - val_loss: 0.3696 - learning_rate: 5.0000e-04
# Epoch 22/200
# 68/68 - 0s - 3ms/step - accuracy: 0.8722 - loss: 0.3279 - val_accuracy: 0.8860 - val_loss: 0.3718 - learning_rate: 2.5000e-04
# Epoch 23/200
# 68/68 - 0s - 3ms/step - accuracy: 0.8814 - loss: 0.3223 - val_accuracy: 0.8860 - val_loss: 0.3742 - learning_rate: 2.5000e-04
# Epoch 24/200
# 68/68 - 0s - 3ms/step - accuracy: 0.8925 - loss: 0.3130 - val_accuracy: 0.8860 - val_loss: 0.3721 - learning_rate: 2.5000e-04
# Epoch 25/200
# 68/68 - 0s - 3ms/step - accuracy: 0.8768 - loss: 0.3220 - val_accuracy: 0.8860 - val_loss: 0.3713 - learning_rate: 2.5000e-04

# %%
# Print versions of PySpark, Python and Spark
import sys, pyspark
print("Python exe:", sys.executable)  
print("PySpark ver:", pyspark.__version__)
print("Spark:", spark.version)
# Out:
# Python exe: /usr/bin/python3
# PySpark ver: 3.5.6
# Spark: 3.5.6
